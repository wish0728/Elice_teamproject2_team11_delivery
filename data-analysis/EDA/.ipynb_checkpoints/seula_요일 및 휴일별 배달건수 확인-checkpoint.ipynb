# %%
# 메인 배달 freq 데이터와 휴일 데이터 결합해서,
# 요일별 배달량 차팅해보기
# 휴일/평일 배달량 차팅해보기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family='AppleGothic')

# %%
delivery_frequency = pd.read_csv('/Users/seulalee/OneDrive/MyStudy/210816_엘리스AI트랙/TeamProject1/Team11_NaplessRabbit/project-template/cleaned_data/시간지역별배달주문건수.csv', index_col=0)
delivery_frequency
# Out:
# /Users/seulalee/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                  날짜  시간대  광역시도       시군구  읍면동  배달건수 요일
# 0        2019-08-01    0   강원도       속초시   교동     1  목
# 1        2019-08-01    0   경기도  고양시 일산동구  마두동     4  목
# 2        2019-08-01    0   경기도  고양시 일산동구  백석동    28  목
# 3        2019-08-01    0   경기도  고양시 일산동구  식사동     3  목
# 4        2019-08-01    0   경기도  고양시 일산동구  장항동     4  목
# ...             ...  ...   ...       ...  ...   ... ..
# 2382976  2021-08-31   23  충청남도   천안시 서북구  쌍용동     6  화
# 2382977  2021-08-31   23  충청북도       제천시  신백동     6  화
# 2382978  2021-08-31   23  충청북도       제천시  신월동     2  화
# 2382979  2021-08-31   23  충청북도       제천시  천남동     1  화
# 2382980  2021-08-31   23  충청북도       제천시  하소동     4  화
#
# [2382981 rows x 7 columns]

# %%
holiday = pd.read_csv('/Users/seulalee/OneDrive/MyStudy/210816_엘리스AI트랙/TeamProject1/Team11_NaplessRabbit/project-template/rawdata/holiday/holiday.csv', index_col=0)
holiday
# Out:
#           date     day_name holiday
# 1   2019-01-01         1월1일       Y
# 2   2019-02-04           설날       Y
# 3   2019-02-05           설날       Y
# 4   2019-02-06           설날       Y
# 5   2019-03-01          삼일절       Y
# 6   2019-05-05         어린이날       Y
# 7   2019-05-06        대체공휴일       Y
# 8   2019-05-12       부처님오신날       Y
# 9   2019-06-06          현충일       Y
# 10  2019-08-15          광복절       Y
# 11  2019-09-12           추석       Y
# 12  2019-09-13           추석       Y
# 13  2019-09-14           추석       Y
# 14  2019-10-03          개천절       Y
# 15  2019-10-09          한글날       Y
# 16  2019-12-25        기독탄신일       Y
# 17  2020-01-01         1월1일       Y
# 18  2020-01-24           설날       Y
# 19  2020-01-25           설날       Y
# 20  2020-01-26           설날       Y
# 21  2020-01-27           설날       Y
# 22  2020-03-01          삼일절       Y
# 23  2020-04-15  제21대 국회의원선거       Y
# 24  2020-04-30       부처님오신날       Y
# 25  2020-05-05         어린이날       Y
# 26  2020-06-06          현충일       Y
# 27  2020-08-15          광복절       Y
# 28  2020-08-17        임시공휴일       Y
# 29  2020-09-30           추석       Y
# 30  2020-10-01           추석       Y
# 31  2020-10-02           추석       Y
# 32  2020-10-03          개천절       Y
# 33  2020-10-09          한글날       Y
# 34  2020-12-25        기독탄신일       Y
# 35  2021-01-01         1월1일       Y
# 36  2021-02-11           설날       Y
# 37  2021-02-12           설날       Y
# 38  2021-02-13           설날       Y
# 39  2021-03-01          삼일절       Y
# 40  2021-05-05         어린이날       Y
# 41  2021-05-19       부처님오신날       Y
# 42  2021-06-06          현충일       Y
# 43  2021-08-15          광복절       Y
# 44  2021-08-16        대체공휴일       Y
# 45  2021-09-20           추석       Y
# 46  2021-09-21           추석       Y
# 47  2021-09-22           추석       Y
# 48  2021-10-03          개천절       Y
# 49  2021-10-04        대체공휴일       Y
# 50  2021-10-09          한글날       Y
# 51  2021-10-11        대체공휴일       Y
# 52  2021-12-25        기독탄신일       Y

# %%
delivery_frequency.dtypes
# Out:
# 날짜      object
# 시간대      int64
# 광역시도    object
# 시군구     object
# 읍면동     object
# 배달건수     int64
# 요일      object
# dtype: object

# %%
holiday.dtypes
# Out:
# date        object
# day_name    object
# holiday     object
# dtype: object

# %%
# 데이터 두 개 걍 합쳐버려야겠다
df = pd.merge(delivery_frequency, holiday, how='left', left_on='날짜', right_on = 'date')
df[df['날짜']=='2019-12-25']
# Out:
#                 날짜  시간대  광역시도       시군구  읍면동  배달건수 요일        date day_name  \
# 404425  2019-12-25    0   경기도   고양시 덕양구  삼송동     3  수  2019-12-25    기독탄신일
# 404426  2019-12-25    0   경기도   고양시 덕양구  행신동    21  수  2019-12-25    기독탄신일
# 404427  2019-12-25    0   경기도   고양시 덕양구  화정동    36  수  2019-12-25    기독탄신일
# 404428  2019-12-25    0   경기도  고양시 일산동구  마두동     3  수  2019-12-25    기독탄신일
# 404429  2019-12-25    0   경기도  고양시 일산동구  백석동    17  수  2019-12-25    기독탄신일
# ...            ...  ...   ...       ...  ...   ... ..         ...      ...
# 407790  2019-12-25   23  충청북도       제천시  영천동     1  수  2019-12-25    기독탄신일
# 407791  2019-12-25   23  충청북도       제천시  장락동     3  수  2019-12-25    기독탄신일
# 407792  2019-12-25   23  충청북도       제천시  천남동     2  수  2019-12-25    기독탄신일
# 407793  2019-12-25   23  충청북도       제천시  청전동     6  수  2019-12-25    기독탄신일
# 407794  2019-12-25   23  충청북도       제천시  하소동     2  수  2019-12-25    기독탄신일
#
#        holiday
# 404425       Y
# 404426       Y
# 404427       Y
# 404428       Y
# 404429       Y
# ...        ...
# 407790       Y
# 407791       Y
# 407792       Y
# 407793       Y
# 407794       Y
#
# [3370 rows x 10 columns]

# %%
# holiday값이 있는 애들만 확인하기
df[df['day_name'].isnull()==False]
# Out:
#                  날짜  시간대  광역시도       시군구  읍면동  배달건수 요일        date day_name  \
# 32640    2019-08-15    0   강원도       속초시   교동     1  목  2019-08-15      광복절
# 32641    2019-08-15    0   경기도   고양시 덕양구  성사동     1  목  2019-08-15      광복절
# 32642    2019-08-15    0   경기도   고양시 덕양구  행신동    15  목  2019-08-15      광복절
# 32643    2019-08-15    0   경기도   고양시 덕양구  화정동    11  목  2019-08-15      광복절
# 32644    2019-08-15    0   경기도  고양시 일산동구  마두동     1  목  2019-08-15      광복절
# ...             ...  ...   ...       ...  ...   ... ..         ...      ...
# 2343769  2021-08-16   23  충청남도   천안시 서북구  쌍용동     5  월  2021-08-16    대체공휴일
# 2343770  2021-08-16   23  충청북도       제천시  신백동     3  월  2021-08-16    대체공휴일
# 2343771  2021-08-16   23  충청북도       제천시  천남동     3  월  2021-08-16    대체공휴일
# 2343772  2021-08-16   23  충청북도       제천시  청전동     5  월  2021-08-16    대체공휴일
# 2343773  2021-08-16   23  충청북도       제천시  하소동     1  월  2021-08-16    대체공휴일
#
#         holiday
# 32640         Y
# 32641         Y
# 32642         Y
# 32643         Y
# 32644         Y
# ...         ...
# 2343769       Y
# 2343770       Y
# 2343771       Y
# 2343772       Y
# 2343773       Y
#
# [107421 rows x 10 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                  날짜  시간대  광역시도       시군구  읍면동  배달건수 요일 date day_name holiday
# 0        2019-08-01    0   강원도       속초시   교동     1  목  NaN      NaN     NaN
# 1        2019-08-01    0   경기도  고양시 일산동구  마두동     4  목  NaN      NaN     NaN
# 2        2019-08-01    0   경기도  고양시 일산동구  백석동    28  목  NaN      NaN     NaN
# 3        2019-08-01    0   경기도  고양시 일산동구  식사동     3  목  NaN      NaN     NaN
# 4        2019-08-01    0   경기도  고양시 일산동구  장항동     4  목  NaN      NaN     NaN
# ...             ...  ...   ...       ...  ...   ... ..  ...      ...     ...
# 2382976  2021-08-31   23  충청남도   천안시 서북구  쌍용동     6  화  NaN      NaN     NaN
# 2382977  2021-08-31   23  충청북도       제천시  신백동     6  화  NaN      NaN     NaN
# 2382978  2021-08-31   23  충청북도       제천시  신월동     2  화  NaN      NaN     NaN
# 2382979  2021-08-31   23  충청북도       제천시  천남동     1  화  NaN      NaN     NaN
# 2382980  2021-08-31   23  충청북도       제천시  하소동     4  화  NaN      NaN     NaN
#
# [2382981 rows x 10 columns]>

# %%
# '날짜'와 중복되는 'date'컬럼 삭제
df.drop(['date'], axis=1, inplace = True)
df
# Out:
#                  날짜  시간대  광역시도       시군구  읍면동  배달건수 요일 day_name holiday
# 0        2019-08-01    0   강원도       속초시   교동     1  목      NaN     NaN
# 1        2019-08-01    0   경기도  고양시 일산동구  마두동     4  목      NaN     NaN
# 2        2019-08-01    0   경기도  고양시 일산동구  백석동    28  목      NaN     NaN
# 3        2019-08-01    0   경기도  고양시 일산동구  식사동     3  목      NaN     NaN
# 4        2019-08-01    0   경기도  고양시 일산동구  장항동     4  목      NaN     NaN
# ...             ...  ...   ...       ...  ...   ... ..      ...     ...
# 2382976  2021-08-31   23  충청남도   천안시 서북구  쌍용동     6  화      NaN     NaN
# 2382977  2021-08-31   23  충청북도       제천시  신백동     6  화      NaN     NaN
# 2382978  2021-08-31   23  충청북도       제천시  신월동     2  화      NaN     NaN
# 2382979  2021-08-31   23  충청북도       제천시  천남동     1  화      NaN     NaN
# 2382980  2021-08-31   23  충청북도       제천시  하소동     4  화      NaN     NaN
#
# [2382981 rows x 9 columns]

# %%
# 휴일 결합한 파일 저장해두기
df.to_csv('/Users/seulalee/OneDrive/MyStudy/210816_엘리스AI트랙/TeamProject1/Team11_NaplessRabbit/project-template/rawdata/holiday/freq_with_holiday.csv')

# %%
# 광역시도 변수의 값 확인
df['광역시도'].unique()
# Out:
# array(['강원도', '경기도', '경상남도', '대전광역시', '서울특별시', '전라남도', '전라북도', '제주특별자치도',
#        '충청남도', '충청북도', '경상북도', '대구광역시', '부산광역시', '광주광역시', '인천광역시',
#        '울산광역시', '세종특별자치시'], dtype=object)

# %% [markdown]
# ## 요일별 배달건수 확인하기
# ### 광역시도-시군구 / x축은 요일, y축은 배달건수 (Mean / Median 값이 얼마나 다르게 나오나?)

# %%
# 용산구 요일별 배달건수
test_frq_day = df[df['시군구']=='용산구'].groupby('요일').mean().reset_index()

fig, ax = plt.subplots(figsize=(12, 4))
ax.bar(test_frq_day['요일'], test_frq_day['배달건수'])
ax.set_title('용산구 요일별 배달건수')
# Out:
# Text(0.5, 1.0, '용산구 요일별 배달건수')

# %%
print(df[df['시군구']=='용산구'].size)
print(df[df['시군구']=='강남구'].size)
# Out:
# 30258
# 39942

# %%
# 강남구 요일별 배달건수
test_frq_day = df[df['시군구']=='강남구'].groupby('요일').mean().reset_index()
fig, ax = plt.subplots(figsize=(12, 4))
ax.bar(test_frq_day['요일'], test_frq_day['배달건수'])
ax.set_title('강남구 요일별 배달건수')
# Out:
# Text(0.5, 1.0, '강남구 요일별 배달건수')

# %%
# 고양시 일산동구 배달건수 - Mean
test_frq_day = df[df['시군구']=='고양시 일산동구'].groupby('요일').mean().reset_index()
fig, ax = plt.subplots(figsize=(12, 4))
ax.bar(test_frq_day['요일'], test_frq_day['배달건수'])
ax.set_title('고양시 일산동구 요일별 배달건수')
# Out:
# Text(0.5, 1.0, '고양시 일산동구 요일별 배달건수')

# %%
# 고양시 일산동구 배달건수 - Median
test_frq_day = df[df['시군구']=='고양시 일산동구'].groupby('요일').median().reset_index()
fig, ax = plt.subplots(figsize=(12, 4))
ax.bar(test_frq_day['요일'], test_frq_day['배달건수'])
ax.set_title('고양시 일산동구 요일별 배달건수')
ax.set_xticks([test_frq_day])
# Out:
# Text(0.5, 1.0, '고양시 일산동구 요일별 배달건수')

# %% [markdown]
# ## 휴일별 배달건수 확인하기

# %%
test_frq_day = df[df['시군구']=='고양시 일산동구'].groupby('day_name').mean().reset_index()
fig, ax = plt.subplots(figsize=(20, 4))
ax.bar(test_frq_day['day_name'], test_frq_day['배달건수'])
ax.set_title('고양시 일산동구 휴일별 배달건수')
# Out:
# Text(0.5, 1.0, '고양시 일산동구 휴일별 배달건수')

# %%
# 비교해서 볼 수 있게, 휴일이 아닌 날도 들어가야하니까 nan값을 채워줘야겠음
df['day_name'] = df['day_name'].fillna('휴일아님')
df['holiday'] = df['holiday'].fillna('N')
df.head(10)

# 휴일 아닌 날을 주말이랑 평일로 나눠서 보여주기
# Out:
#            날짜  시간대 광역시도       시군구   읍면동  배달건수 요일 day_name holiday
# 0  2019-08-01    0  강원도       속초시    교동     1  목     휴일아님       N
# 1  2019-08-01    0  경기도  고양시 일산동구   마두동     4  목     휴일아님       N
# 2  2019-08-01    0  경기도  고양시 일산동구   백석동    28  목     휴일아님       N
# 3  2019-08-01    0  경기도  고양시 일산동구   식사동     3  목     휴일아님       N
# 4  2019-08-01    0  경기도  고양시 일산동구   장항동     4  목     휴일아님       N
# 5  2019-08-01    0  경기도  고양시 일산동구  정발산동     2  목     휴일아님       N
# 6  2019-08-01    0  경기도  고양시 일산서구   일산동     7  목     휴일아님       N
# 7  2019-08-01    0  경기도  고양시 일산서구   탄현동     3  목     휴일아님       N
# 8  2019-08-01    0  경기도       광명시   광명동     9  목     휴일아님       N
# 9  2019-08-01    0  경기도       광명시   철산동    13  목     휴일아님       N

# %% [markdown]
# ### 공휴일 정보에서 휴일이 아닌 날을 기준으로 배달이 많았던 날과 배달이 적었던 날을 가려보고 차이가 왜 생겼는지 확인 필요할듯....

# %%
df.광역시도.nunique()
# Out:
# 17
